# %%
import pandas as pd 
import seaborn as sns 
import matplotlib.pyplot as plt
import numpy as np
import plotly.express as px

# %%
	
# Load dataset 
def load_dataset(file_path): return pd.read_csv(file_path) 
df = load_dataset("/Users/rijanbhandari/COLLEGE/sixthsem/minorproject/Pahiran/anime/archive 2/final_animedataset.csv") 
df.head()
# Out:
#    username  anime_id  my_score  user_id  gender          title type source  \
# 0  karthiga        21         9  2255153  Female      One Piece   TV  Manga
# 1  karthiga        59         7  2255153  Female        Chobits   TV  Manga
# 2  karthiga        74         7  2255153  Female   Gakuen Alice   TV  Manga
# 3  karthiga       120         7  2255153  Female  Fruits Basket   TV  Manga
# 4  karthiga       178         7  2255153  Female   Ultra Maniac   TV  Manga
#
#    score  scored_by    rank  popularity  \
# 0   8.54     423868    91.0          35
# 1   7.53     175388  1546.0         188
# 2   7.77      33244   941.0        1291
# 3   7.77     167968   939.0         222
# 4   7.26       9663  2594.0        2490
#
#                                                genre
# 0  Action, Adventure, Comedy, Super Power, Drama,...
# 1      Sci-Fi, Comedy, Drama, Romance, Ecchi, Seinen
# 2                Comedy, School, Shoujo, Super Power
# 3  Slice of Life, Comedy, Drama, Romance, Fantasy...
# 4             Magic, Comedy, Romance, School, Shoujo

# %%
# Categorical data
 # countplot 
sns.countplot(data=df, x='gender')
# Out:
# <Axes: xlabel='gender', ylabel='count'>

# %%
df['gender'].value_counts()
# Out:
# gender
# Male          25386353
# Female         9678908
# Non-Binary      240434
# Name: count, dtype: int64

# %%
# pie chart 
df['gender'].value_counts().plot(kind='pie',autopct='%0.2f')
plt.title('Gender')
# Out:
# Text(0.5, 1.0, 'Gender')

# %%
# Numberical Value
# Histogram treat as categorical data distribution of data
plt.hist(df['popularity'], bins=10, edgecolor='black', alpha=0.7)
plt.title('Histogram of Popularity')
plt.xlabel('Popularity')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %%
plt.hist(df['rank'])
plt.title('Histogram of Anime Ranks')
plt.xlabel('Rank')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %%
# Distplot # probability density function --> 
# The line is kde # skweness 
sns.distplot(df['score'])
# Out:
# /var/folders/bn/2nh7p1hx30v1yj4_htdlml7c0000gn/T/ipykernel_42246/74297351.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['score'])
# <Axes: xlabel='score', ylabel='Density'>

# %%
# Boxplot # 5 number summary # median , percentile,min=Q1-1.5*IQR, max=Q3+1.5*IQR, IQR = (Q1-Q3), outlier
sns.boxplot(df['score'])
# Out:
# <Axes: ylabel='score'>

# %%
df.describe()
# Out:
#            anime_id      my_score       user_id         score     scored_by  \
# count  3.530570e+07  3.530570e+07  3.530570e+07  3.530570e+07  3.530570e+07
# mean   1.148159e+04  4.591388e+00  1.863856e+06  7.527708e+00  1.096508e+05
# std    1.121719e+04  3.909503e+00  1.963096e+06  7.279344e-01  1.479300e+05
# min    1.000000e+00  0.000000e+00  1.000000e+00  1.900000e+00  2.000000e+02
# 25%    1.661000e+03  0.000000e+00  2.130750e+05  7.110000e+00  1.737600e+04
# 50%    7.724000e+03  6.000000e+00  1.057347e+06  7.560000e+00  5.388100e+04
# 75%    1.911700e+04  8.000000e+00  3.557933e+06  8.030000e+00  1.396270e+05
# max    3.786300e+04  1.000000e+01  7.251737e+06  9.250000e+00  1.009477e+06
#
#                rank    popularity
# count  3.455372e+07  3.530570e+07
# mean   2.045874e+03  1.335952e+03
# std    1.972325e+03  1.563161e+03
# min    1.000000e+00  1.000000e+00
# 25%    5.000000e+02  2.510000e+02
# 50%    1.414000e+03  7.690000e+02
# 75%    3.039000e+03  1.824000e+03
# max    9.527000e+03  1.026500e+04

# %%
sns.scatterplot(x='score', y='my_score', hue='gender', style='rank', size='popularity', data=df)
# Out:
# <Axes: xlabel='score', ylabel='my_score'>
# Error in callback <function _draw_all_if_interactive at 0x12f954d30> (for post_execute), with arguments args (),kwargs {}:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File ~/COLLEGE/sixthsem/minorproject/Pahiran/environment/lib/python3.10/site-packages/matplotlib/pyplot.py:120, in _draw_all_if_interactive()
#     118 def _draw_all_if_interactive():
#     119     if matplotlib.is_interactive():
# --> 120         draw_all()
#
# File ~/COLLEGE/sixthsem/minorproject/Pahiran/environment/lib/python3.10/site-packages/matplotlib/_pylab_helpers.py:132, in Gcf.draw_all(cls, force)
#     130 for manager in cls.get_all_fig_managers():
#     131     if force or manager.canvas.figure.stale:
# --> 132         manager.canvas.draw_idle()
#
# File ~/COLLEGE/sixthsem/minorproject/Pahiran/environment/lib/python3.10/site-packages/matplotlib/backend_bases.py:2082, in FigureCanvasBase.draw_idle(self, *args, **kwargs)
#    2080 if not self._is_idle_drawing:
#    2081     with self._idle_draw_cntx():
# -> 2082         self.draw(*args, **kwargs)
#
# File ~/COLLEGE/sixthsem/minorproject/Pahiran/environment/lib/python3.10/site-packages/matplotlib/backends/backend_agg.py:400, in FigureCanvasAgg.draw(self)
#     396 # Acquire a lock on the shared font cache.
#     397 with RendererAgg.lock, \
#     398      (self.toolbar._wait_cursor_for_draw_cm() if self.toolbar
#     399       else nullcontext()):
# --> 400     self.figure.draw(self.renderer)
#     401     # A GUI class may be need to update a window using this draw, so
#     402     # don't forget to call the superclass.
#     403     super().draw()
#
# File ~/COLLEGE/sixthsem/minorproject/Pahiran/environment/lib/python3.10/site-packages/matplotlib/artist.py:95, in _finalize_rasterization.<locals>.draw_wrapper(artist, renderer, *args, **kwargs)
#      93 @wraps(draw)
#      94 def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 95     result = draw(artist, renderer, *args, **kwargs)
#      96     if renderer._rasterizing:
#      97         renderer.stop_rasterizing()
#
# File ~/COLLEGE/sixthsem/minorproject/Pahiran/environment/lib/python3.10/site-packages/matplotlib/artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      69     if artist.get_agg_filter() is not None:
#      70         renderer.start_filter()
# ---> 72     return draw(artist, renderer)
#      73 finally:
#      74     if artist.get_agg_filter() is not None:
#
# File ~/COLLEGE/sixthsem/minorproject/Pahiran/environment/lib/python3.10/site-packages/matplotlib/figure.py:3175, in Figure.draw(self, renderer)
#    3172         # ValueError can occur when resizing a window.
#    3174 self.patch.draw(renderer)
# -> 3175 mimage._draw_list_compositing_images(
#    3176     renderer, self, artists, self.suppressComposite)
#    3178 for sfig in self.subfigs:
#    3179     sfig.draw(renderer)
#
# File ~/COLLEGE/sixthsem/minorproject/Pahiran/environment/lib/python3.10/site-packages/matplotlib/image.py:131, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     129 if not_composite or not has_images:
#     130     for a in artists:
# --> 131         a.draw(renderer)
#     132 else:
#     133     # Composite any adjacent images together
#     134     image_group = []
#
# File ~/COLLEGE/sixthsem/minorproject/Pahiran/environment/lib/python3.10/site-packages/matplotlib/artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      69     if artist.get_agg_filter() is not None:
#      70         renderer.start_filter()
# ---> 72     return draw(artist, renderer)
#      73 finally:
#      74     if artist.get_agg_filter() is not None:
#
# File ~/COLLEGE/sixthsem/minorproject/Pahiran/environment/lib/python3.10/site-packages/matplotlib/axes/_base.py:3064, in _AxesBase.draw(self, renderer)
#    3061 if artists_rasterized:
#    3062     _draw_rasterized(self.figure, artists_rasterized, renderer)
# -> 3064 mimage._draw_list_compositing_images(
#    3065     renderer, self, artists, self.figure.suppressComposite)
#    3067 renderer.close_group('axes')
#    3068 self.stale = False
#
# File ~/COLLEGE/sixthsem/minorproject/Pahiran/environment/lib/python3.10/site-packages/matplotlib/image.py:131, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     129 if not_composite or not has_images:
#     130     for a in artists:
# --> 131         a.draw(renderer)
#     132 else:
#     133     # Composite any adjacent images together
#     134     image_group = []
#
# File ~/COLLEGE/sixthsem/minorproject/Pahiran/environment/lib/python3.10/site-packages/matplotlib/artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      69     if artist.get_agg_filter() is not None:
#      70         renderer.start_filter()
# ---> 72     return draw(artist, renderer)
#      73 finally:
#      74     if artist.get_agg_filter() is not None:
#
# File ~/COLLEGE/sixthsem/minorproject/Pahiran/environment/lib/python3.10/site-packages/matplotlib/collections.py:972, in _CollectionWithSizes.draw(self, renderer)
#     969 @artist.allow_rasterization
#     970 def draw(self, renderer):
#     971     self.set_sizes(self._sizes, self.figure.dpi)
# --> 972     super().draw(renderer)
#
# File ~/COLLEGE/sixthsem/minorproject/Pahiran/environment/lib/python3.10/site-packages/matplotlib/artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      69     if artist.get_agg_filter() is not None:
#      70         renderer.start_filter()
# ---> 72     return draw(artist, renderer)
#      73 finally:
#      74     if artist.get_agg_filter() is not None:
#
# File ~/COLLEGE/sixthsem/minorproject/Pahiran/environment/lib/python3.10/site-packages/matplotlib/collections.py:409, in Collection.draw(self, renderer)
#     405     renderer.draw_markers(
#     406         gc, paths[0], combined_transform.frozen(),
#     407         mpath.Path(offsets), offset_trf, tuple(facecolors[0]))
#     408 else:
# --> 409     renderer.draw_path_collection(
#     410         gc, transform.frozen(), paths,
#     411         self.get_transforms(), offsets, offset_trf,
#     412         self.get_facecolor(), self.get_edgecolor(),
#     413         self._linewidths, self._linestyles,
#     414         self._antialiaseds, self._urls,
#     415         "screen")  # offset_position, kept for backcompat.
#     417 gc.restore()
#     418 renderer.close_group(self.__class__.__name__)
#
# File ~/COLLEGE/sixthsem/minorproject/Pahiran/environment/lib/python3.10/site-packages/matplotlib/path.py:211, in Path.vertices(self)
#     203     self._simplify_threshold = mpl.rcParams['path.simplify_threshold']
#     204     self._should_simplify = (
#     205         self._simplify_threshold > 0 and
#     206         mpl.rcParams['path.simplify'] and
#     207         len(self._vertices) >= 128 and
#     208         (self._codes is None or np.all(self._codes <= Path.LINETO))
#     209     )
# --> 211 @property
#     212 def vertices(self):
#     213     """
#     214     The list of vertices in the `Path` as an Nx2 numpy array.
#     215     """
#     216     return self._vertices
#
# KeyboardInterrupt:

# %%
# Bar plot (Numerical - Categorical) # average age in pclass
sns.barplot(x='title',y='popularity',hue='gender',data=df)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 2
#       1 # Bar plot (Numerical - Categorical) # average age in pclass
# ----> 2 sns.barplot(x='title',y='popularity',hue='gender',data=df)
#
# File ~/COLLEGE/sixthsem/minorproject/Pahiran/environment/lib/python3.10/site-packages/seaborn/categorical.py:2379, in barplot(data, x, y, hue, order, hue_order, estimator, errorbar, n_boot, seed, units, weights, orient, color, palette, saturation, fill, hue_norm, width, dodge, gap, log_scale, native_scale, formatter, legend, capsize, err_kws, ci, errcolor, errwidth, ax, **kwargs)
#    2376 # Deprecations to remove in v0.15.0.
#    2377 err_kws, capsize = p._err_kws_backcompat(err_kws, errcolor, errwidth, capsize)
# -> 2379 p.plot_bars(
#    2380     aggregator=aggregator,
#    2381     dodge=dodge,
#    2382     width=width,
#    2383     gap=gap,
#    2384     color=color,
#    2385     fill=fill,
#    2386     capsize=capsize,
#    2387     err_kws=err_kws,
#    2388     plot_kws=kwargs,
#    2389 )
#    2391 p._add_axis_labels(ax)
#    2392 p._adjust_cat_axis(ax, axis=p.orient)
#
# File ~/COLLEGE/sixthsem/minorproject/Pahiran/environment/lib/python3.10/site-packages/seaborn/categorical.py:1281, in _CategoricalPlotter.plot_bars(self, aggregator, dodge, gap, width, fill, color, capsize, err_kws, plot_kws)
#    1272 for sub_vars, sub_data in self.iter_data(iter_vars,
#    1273                                          from_comp_data=True,
#    1274                                          allow_empty=True):
#    1276     ax = self._get_axes(sub_vars)
#    1278     agg_data = sub_data if sub_data.empty else (
#    1279         sub_data
#    1280         .groupby(self.orient)
# -> 1281         .apply(aggregator, agg_var)
#    1282         .reset_index()
#    1283     )
#    1285     agg_data["width"] = width * self._native_width
#    1286     if dodge:
#
# File ~/COLLEGE/sixthsem/minorproject/Pahiran/environment/lib/python3.10/site-packages/pandas/core/groupby/groupby.py:1770, in GroupBy.apply(self, func, *args, **kwargs)
#    1768 with option_context("mode.chained_assignment", None):
#    1769     try:
# -> 1770         result = self._python_apply_general(f, self._selected_obj)
#    1771     except TypeError:
#    1772         # gh-20949
#    1773         # try again, with .apply acting as a filtering
#    (...)
#    1777         # fails on *some* columns, e.g. a numeric operation
#    1778         # on a string grouper column
#    1780         return self._python_apply_general(f, self._obj_with_exclusions)
#
# File ~/COLLEGE/sixthsem/minorproject/Pahiran/environment/lib/python3.10/site-packages/pandas/core/groupby/groupby.py:1819, in GroupBy._python_apply_general(self, f, data, not_indexed_same, is_transform, is_agg)
#    1784 @final
#    1785 def _python_apply_general(
#    1786     self,
#    (...)
#    1791     is_agg: bool = False,
#    1792 ) -> NDFrameT:
#    1793     """
#    1794     Apply function f in python space
#    1795
#    (...)
#    1817         data after applying f
#    1818     """
# -> 1819     values, mutated = self.grouper.apply_groupwise(f, data, self.axis)
#    1820     if not_indexed_same is None:
#    1821         not_indexed_same = mutated
#
# File ~/COLLEGE/sixthsem/minorproject/Pahiran/environment/lib/python3.10/site-packages/pandas/core/groupby/ops.py:911, in BaseGrouper.apply_groupwise(self, f, data, axis)
#     909 # group might be modified
#     910 group_axes = group.axes
# --> 911 res = f(group)
#     912 if not mutated and not _is_indexed_like(res, group_axes, axis):
#     913     mutated = True
#
# File ~/COLLEGE/sixthsem/minorproject/Pahiran/environment/lib/python3.10/site-packages/pandas/core/groupby/groupby.py:1758, in GroupBy.apply.<locals>.f(g)
#    1756 @wraps(func)
#    1757 def f(g):
# -> 1758     return func(g, *args, **kwargs)
#
# File ~/COLLEGE/sixthsem/minorproject/Pahiran/environment/lib/python3.10/site-packages/seaborn/_statistics.py:517, in EstimateAggregator.__call__(self, data, var)
#     515 elif self.error_method == "ci":
#     516     units = data.get("units", None)
# --> 517     boots = bootstrap(vals, units=units, func=self.estimator, **self.boot_kws)
#     518     err_min, err_max = _percentile_interval(boots, self.error_level)
#     520 return pd.Series({var: estimate, f"{var}min": err_min, f"{var}max": err_max})
#
# File ~/COLLEGE/sixthsem/minorproject/Pahiran/environment/lib/python3.10/site-packages/seaborn/algorithms.py:98, in bootstrap(*args, **kwargs)
#      96 boot_dist = []
#      97 for i in range(int(n_boot)):
# ---> 98     resampler = integers(0, n, n, dtype=np.intp)  # intp is indexing dtype
#      99     sample = [a.take(resampler, axis=0) for a in args]
#     100     boot_dist.append(f(*sample, **func_kwargs))
#
# KeyboardInterrupt:
# /Users/rijanbhandari/COLLEGE/sixthsem/minorproject/Pahiran/environment/lib/python3.10/site-packages/IPython/core/events.py:82: UserWarning: Glyph 65290 (\N{FULLWIDTH ASTERISK}) missing from current font.
#   func(*args, **kwargs)

# %%
# Distribution plot of 'my_score' for each anime type

sns.distplot(df[df['type'] == 'TV']['my_score'], hist=False, label='TV')
sns.distplot(df[df['type'] == 'Movie']['my_score'], hist=False, label='Movie')
plt.title('Distribution of My Score by Anime Type')
plt.xlabel('My Score')
plt.ylabel('Density')

plt.show()
# Out:
# /var/folders/bn/2nh7p1hx30v1yj4_htdlml7c0000gn/T/ipykernel_3906/1446389367.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[df['type'] == 'TV']['my_score'], hist=False, label='TV')
# /var/folders/bn/2nh7p1hx30v1yj4_htdlml7c0000gn/T/ipykernel_3906/1446389367.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[df['type'] == 'Movie']['my_score'], hist=False, label='Movie')

# %%
sns.distplot(df['rank'], kde=True, hist=True, color='skyblue')
plt.title('Distribution of Ranks for Anime')
plt.xlabel('Rank')
plt.ylabel('Density')
plt.show()
# Out:
# /var/folders/bn/2nh7p1hx30v1yj4_htdlml7c0000gn/T/ipykernel_3906/700901262.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['rank'], kde=True, hist=True, color='skyblue')

# %%
# HeatMap (Categorical - Categorical)
sns.heatmap(pd.crosstab(df['gender'],df['type']))
plt.show()

# %%
mean_type_by_gender = df.groupby('gender')['type'].mean() * 100
print(mean_type_by_gender)

# %%
sns.pairplot(df[['type']], hue='type')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 2
#       1 # pairplot
# ----> 2 sns.pairplot(type,hue='type')
#
# File ~/COLLEGE/sixthsem/minorproject/Pahiran/environment/lib/python3.10/site-packages/seaborn/axisgrid.py:2103, in pairplot(data, hue, hue_order, palette, vars, x_vars, y_vars, kind, diag_kind, markers, height, aspect, corner, dropna, plot_kws, diag_kws, grid_kws, size)
#    2100     warnings.warn(msg, UserWarning)
#    2102 if not isinstance(data, pd.DataFrame):
# -> 2103     raise TypeError(
#    2104         f"'data' must be pandas DataFrame object, not: {type(data)}")
#    2106 plot_kws = {} if plot_kws is None else plot_kws.copy()
#    2107 diag_kws = {} if diag_kws is None else diag_kws.copy()
#
# TypeError: 'data' must be pandas DataFrame object, not: <class 'type'>

# %%
# Count the number of anime titles by type
type_counts = df['type'].value_counts()

# Create a bar chart
fig = px.bar(type_counts, x=type_counts.index, y=type_counts.values, color=type_counts.index, labels={'x':'Anime Type', 'y':'Count'}, 
             title='Count of Anime Titles by type')

fig.show()

# %%
# Importing anime details dataframe
df_anime=pd.read_csv('anime/archive 2/anime-dataset-2023.csv')
print("Shape of the Dataset:",df_anime.shape)
df_anime.head(3)
# Out:
# Shape of the Dataset: (24905, 24)
#    anime_id                             Name             English name  \
# 0         1                     Cowboy Bebop             Cowboy Bebop
# 1         5  Cowboy Bebop: Tengoku no Tobira  Cowboy Bebop: The Movie
# 2         6                           Trigun                   Trigun
#
#        Other name Score                         Genres  \
# 0       カウボーイビバップ  8.75  Action, Award Winning, Sci-Fi
# 1  カウボーイビバップ 天国の扉  8.38                 Action, Sci-Fi
# 2           トライガン  8.22      Action, Adventure, Sci-Fi
#
#                                             Synopsis   Type Episodes  \
# 0  Crime is timeless. By the year 2071, humanity ...     TV     26.0
# 1  Another day, another bounty—such is the life o...  Movie      1.0
# 2  Vash the Stampede is the man with a $$60,000,0...     TV     26.0
#
#                          Aired  ...   Studios    Source       Duration  \
# 0  Apr 3, 1998 to Apr 24, 1999  ...   Sunrise  Original  24 min per ep
# 1                  Sep 1, 2001  ...     Bones  Original    1 hr 55 min
# 2  Apr 1, 1998 to Sep 30, 1998  ...  Madhouse     Manga  24 min per ep
#
#                            Rating   Rank Popularity Favorites Scored By  \
# 0  R - 17+ (violence & profanity)   41.0         43     78525  914193.0
# 1  R - 17+ (violence & profanity)  189.0        602      1448  206248.0
# 2       PG-13 - Teens 13 or older  328.0        246     15035  356739.0
#
#    Members                                          Image URL
# 0  1771505  https://cdn.myanimelist.net/images/anime/4/196...
# 1   360978  https://cdn.myanimelist.net/images/anime/1439/...
# 2   727252  https://cdn.myanimelist.net/images/anime/7/203...
#
# [3 rows x 24 columns]

# %%
# Count the number of anime titles by type
type_counts = df_anime['Type'].value_counts()

# Create a bar chart
fig = px.bar(type_counts, x=type_counts.index, y=type_counts.values, color=type_counts.index, labels={'x':'Anime Type', 'y':'Count'}, 
             title='Count of Anime Titles by Type')

fig.show()

# %%
# Create a scatter plot
fig = px.scatter(df_anime, x='Score', y='Members', 
                 labels={'Score':'Overall Score', 'Members':'Number of Scores'}, 
                 title='Anime Score vs. Number of Scores')

fig.show()

# %%
# Sort the dataframe by the number of users who have scored the anime
top_15_scored = df_anime.sort_values(by='Members', ascending=False).head(15)

# Create a bar chart
fig = px.bar(top_15_scored, x='Name', y='Members', labels={'Members':'Number of Users', 'Name':'Anime Title'},color='Name',
             title='Top 15 Animes by Number of Users')

fig.show()

# %%
# Sort the dataframe by the number of users who have scored the anime
top_15_scored = df_anime.sort_values(by='Members', ascending=False).head(15)

# Create a bar chart
fig = px.bar(top_15_scored, x='Name', y='Members', labels={'Members':'Number of Users', 'Name':'Anime Title'},color='Name',
             title='Top 15 Animes by Number of Users')

fig.show()

# %%
# Split the genres and count their occurrences
genre_counts = df_anime[df_anime['Genres'] != "UNKNOWN"]['Genres'].apply(lambda x: x.split(', ')).explode().value_counts()

# Create a bar chart
fig = px.bar(genre_counts, x=genre_counts.index, y=genre_counts.values,
             labels={'x':'Genre', 'y':'Count'},
             title='Count of Anime Titles by Genre',
             color=genre_counts.index)

fig.show()

# %%
# Select the top 20 genres
top_20_genres = genre_counts.head(20)

# Create a bar chart with custom style
fig = px.bar(top_20_genres, x=top_20_genres.index, y=top_20_genres.values,
             labels={'x':'Genre', 'y':'Count'},
             title='Top 20 Most Popular Genres In The Anime Industry')

# Customize the bar chart appearance
fig.update_traces(marker_color='rgb(158,202,225)', marker_line_color='rgb(8,48,107)',
                  marker_line_width=1.5, opacity=0.8)

fig.update_layout(xaxis_tickangle=-45, xaxis=dict(tickfont=dict(size=12)),
                  yaxis=dict(titlefont=dict(size=14)))

fig.show()
